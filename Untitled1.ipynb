# %%
# !wget -O example_output_file.html https://jirahq:8443/sr/jira.issueviews:searchrequest-xml/temp/SearchRequest.xml?jqlQuery=project+%3D+MET+AND+created+%3E%3D+2019-02-07
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
url = "https://jirahq:8443/sr/jira.issueviews:searchrequest-xml/temp/SearchRequest.xml?jqlQuery=project+%3D+MET+AND+created+%3E%3D+2019-02-07"
response = requests.get(url, stream=True)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1545         else:
# -> 1546             _raise_current_error()
#    1547
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\_util.py in exception_from_error_queue(exception_type)
#      53
# ...
